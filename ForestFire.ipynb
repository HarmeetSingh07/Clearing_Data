# %% [markdown]
# ## Necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading Dataset

# %%
FF = pd.read_table('D:/Data/Datasets/forest_fires.csv',sep=(","))

# %%
FF
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]

# %% [markdown]
# ## Unique Values in FF

# %%
FF['X'].unique()
# Out:
# array([7, 8, 6, 5, 4, 2, 9, 1, 3], dtype=int64)

# %%
FF['Y'].unique()
# Out:
# array([5, 4, 6, 3, 2, 9, 8], dtype=int64)

# %%
FF['month'].unique()
# Out:
# array(['mar', 'oct', 'aug', 'sep', 'apr', 'jun', 'jul', 'feb', 'jan',
#        'dec', 'may', 'nov'], dtype=object)

# %%
FF['FFMC'].unique()
# Out:
# array([86.2, 90.6, 91.7, 89.3, 92.3, 91.5, 91. , 92.5, 92.8, 63.5, 90.9,
#        92.9, 93.3, 84.9, 89.2, 86.3, 91.8, 94.3, 90.2, 93.5, 91.4, 92.4,
#        93.4, 88.6, 90.3, 90. , 88.1, 79.5, 94.8, 90.1, 94.2, 87.2, 87.6,
#        92.1, 92.6, 84. , 86.6, 93. , 91.1, 91.2, 88.8, 84.2, 89.7, 83.9,
#        69. , 82.1, 85.9, 84.4, 68.2, 93.7, 85.8, 95.5, 95.2, 96. , 85.6,
#        81.5, 86.8, 93.9, 90.8, 90.7, 88.3, 92.2, 81.9, 88. , 83. , 93.1,
#        91.9, 91.6, 87.5, 93.6, 84.6, 85.4, 84.7, 86.9, 85.2, 90.4, 53.4,
#        85.1, 89.6, 50.4, 88.2, 92. , 18.7, 90.5, 84.1, 85. , 87.9, 94.6,
#        87.1, 92.7, 88.9, 89.4, 94. , 75.1, 91.3, 93.2, 94.9, 95. , 95.1,
#        95.8, 95.9, 96.2, 96.1, 94.5, 81.6, 94.4])

# %%
FF['DMC'].unique()
# Out:
# array([ 26.2,  35.4,  43.7,  33.3,  51.3,  85.3,  88.9, 145.4, 129.5,
#         88. ,  73.2,  70.8, 126.5, 133.3, 141.2,  35.8,  32.8,  27.9,
#         27.4,  78.5,  96.3, 110.9, 139.4, 142.4, 117.9, 149.3,  85.1,
#         91.8,  69.7,  75.6,  80.7,  41.5,  25.7,  60.6,  96.9, 108.3,
#         82.9,  62.3,  23.9,  52.2, 137. ,  99.6, 111.2, 114.3,  46.5,
#          9.3,  13.2,  75.3, 103.2,  48.3, 147.3,   6.8, 108. , 121.2,
#         90. ,   8. ,   2.4, 121.1,   3.7,  19.5,  30.7,  39.7, 124.1,
#         73.4,  37.9,  21.5,  80.9,  99.9, 131.7,  56.4,  68.6,  51.2,
#         50.1,  18.2, 127.1,  90.4,   9.1,  15.6,  48.5, 135.7,  41.9,
#         44. ,  37.6,   8.7, 150.3,  81.8,   3. ,  17.2,  23.3, 122.3,
#        175.1,  91.6, 157.3, 109.2, 138.1,  77. , 117.2, 170.9,  97.9,
#        112.4, 141.1, 167.6, 102.2, 152.6,  27.2,  27.8,  26.4,  25.4,
#         26.7,  27.5,   6.6,   4.9, 169.7, 183.1, 104.2, 100.2, 180.4,
# ...

# %%
FF.dtypes
# Out:
# X          int64
# Y          int64
# month     object
# day       object
# FFMC     float64
# DMC      float64
# DC       float64
# ISI      float64
# temp     float64
# RH         int64
# wind     float64
# rain     float64
# area     float64
# dtype: object

# %%
FF['DC'].unique()
# Out:
# array([ 94.3, 669.1, 686.9,  77.5, 102.2, 488. , 495.6, 608.2, 692.6,
#        698.6, 713. , 665.3, 686.5, 699.6, 713.9,  80.8, 664.2,  70.8,
#         97.1, 724.3, 200. , 537.4, 594.2, 601.4, 668. , 721.4, 728.6,
#        692.3, 709.9, 706.8, 718.3, 730.2, 682.6,  67.6, 366.7, 624.2,
#        647.1, 735.7, 442.9,  64.7, 103.8, 706.4, 631.2, 654.1, 661.3,
#        691.8,  34. ,  43. , 466.6, 638.8,  97.8, 614.5,  26.6, 529.8,
#        561.6, 704.4,  30.2,  15.5, 674.4,   9.3,  57.3,  74.3,  86.6,
#        680.7, 671.9, 673.8,  87.2, 685.2, 313.4, 513.3, 296.3, 578.8,
#        433.3, 355.2, 424.1, 100.4,  55. , 570.5, 609.6,  55.2,  48.3,
#        696.1, 586.7,  89.4,  92.4,  83.7,  32.1, 309.9, 480.8,   7.9,
#         43.5,  85.3, 589.9, 700.7, 503.6, 666.7, 565.5, 621.7, 694.8,
#        581.1, 542. , 573. , 629.1, 684.4, 550.3, 607.1, 658.2, 353.5,
#        354.6, 352. , 349.7, 352.6,  18.7,  15.8, 411.8, 437.7, 474.9,
# ...

# %%
FF['ISI'].unique()
# Out:
# array([ 5.1,  6.7,  9. ,  9.6, 14.7,  8.5, 10.7,  7. ,  7.1, 22.6,  0.8,
#         9.2, 13.9,  7.8,  3. ,  6.3, 56.1,  6.2, 20.3, 10.6, 12.2,  8.1,
#        15.9,  5.8,  8.7,  3.8,  1.5,  8.9, 17. , 11. ,  4.1,  5. ,  8.8,
#         2.1,  5.3,  7.7, 12.5,  4.8,  2.6,  0.7,  8.6,  2.9,  2.8,  7.5,
#         3.2,  5.2, 17.9,  3.9, 13.2, 10.4,  7.2, 16.5,  6.6,  2.7, 11.1,
#        15.1,  7.9,  5.5,  6.8, 11.9,  3.5,  2.3, 12.9, 13.8, 13.5,  8. ,
#        13.7, 14.4, 13. , 14.6, 22.7, 14.3,  2. ,  3.4, 12.3,  6.4, 12.7,
#         0.4,  5.7,  9.9,  5.4,  8.4,  9.5,  6.5, 10.2, 11.6,  7.4,  8.2,
#         0. , 18. ,  7.6, 11.4, 12. ,  2.2, 14. ,  8.3,  3.7,  4. , 12.1,
#         3.3,  9.8, 10.1,  5.6,  9.7, 16.8, 16.3, 16.7,  1.9,  1.8,  7.3,
#         4.7,  9.4, 10.8, 14.1, 21.3, 17.7, 11.3, 20. ,  1.1])

# %% [markdown]
# ## Check if any value is Null

# %%
FF.isnull().sum()
# Out:
# X        0
# Y        0
# month    0
# day      0
# FFMC     0
# DMC      0
# DC       0
# ISI      0
# temp     0
# RH       0
# wind     0
# rain     0
# area     0
# dtype: int64

# %% [markdown]
# ## Styling

# %%
sns.set(style='darkgrid')

# %% [markdown]
# ## Graphs and Observations

# %%
sns.relplot(kind = 'scatter',x ='month',y = 'day',data=FF,height=6,aspect=2,size = 'FFMC',)

# %% [markdown]
# It shows how the FFMC is increasing and decreasing throughout the year .At some point like in month of "jan" day "sun" FFMC is depleting.

# %%
sns.relplot(kind = 'scatter',x ='month',y = 'day',data=FF,height=6,aspect=2,size = 'DMC')

# %% [markdown]
# As you can see in the Above Graph.The Bigger dots represents the increament and the small dots represent the decreament in DMC throughout the year.

# %%
sns.relplot(kind = 'scatter',x ='month',y = 'day',data=FF,size = 'ISI',height=6,aspect=2)

# %% [markdown]
# It also shows the increase and decrease rate in ISI as the month and day is passing.On month of "jun" day "sun" there is an increament in ISI

# %% [markdown]
# As you can see here in this graph when you check the month of ,Sep,Aug,Jul and  DC is in increasing rate

# %%
sns.relplot(kind = 'scatter',x ='month',y = 'day',data=FF,size= 'DC',height=6,aspect=2)

# %% [markdown]
# But at some points DC is also decreasing like you can check in the above graph after feb

# %% [markdown]
# ### Observation

# %% [markdown]
# Almost every month shows similar things as "FFMC" or "DMC" or "DC" or "ISI" is Increasing or Decreasing per Day

# %%
sns.relplot(x='temp',y='area',data=FF,kind='line');

# %% [markdown]
# This above graph show increasing in temperature indirectly results in area depletion.

# %%
sns.relplot(x=sorted(FF.month),y='area',data=FF,kind='line');

# %% [markdown]
# Same observation of depletion of area over breif period of months.

# %%
sns.lineplot(x='rain',y='RH',data=FF);

# %% [markdown]
# This graph shows relation of humidity with rain, as humidity increases rain start and with continous rain humidity decreases.

# %%
sns.lineplot(x='rain',y='RH',data=FF,hue='month',sort=True)
# Out:
# <AxesSubplot:xlabel='rain', ylabel='RH'>

# %% [markdown]
# This graph shows relation between Humidity and Rainfall

# %% [markdown]
# #### Observation
#
# Almost every month shows smillar relation, as humidity increases causes rainfall but in month of August rainfall increases within range of 70-60 RH level.

# %%
sns.lineplot(x='wind',y='temp',data=FF)
# Out:
# <AxesSubplot:xlabel='wind', ylabel='temp'>

# %% [markdown]
# This graph shows as speed of wind increases temperature tends to drop at some point.

# %%
sns.barplot(x='month',y='temp',data=FF)
# Out:
# <AxesSubplot:xlabel='month', ylabel='temp'>

# %% [markdown]
# This graph simply shows variation of temperature over period of months.

# %%
FF.corr()
# Out:
#              X         Y      FFMC       DMC        DC       ISI      temp  \
# X     1.000000  0.539548 -0.021039 -0.048384 -0.085916  0.006210 -0.051258
# Y     0.539548  1.000000 -0.046308  0.007782 -0.101178 -0.024488 -0.024103
# FFMC -0.021039 -0.046308  1.000000  0.382619  0.330512  0.531805  0.431532
# DMC  -0.048384  0.007782  0.382619  1.000000  0.682192  0.305128  0.469594
# DC   -0.085916 -0.101178  0.330512  0.682192  1.000000  0.229154  0.496208
# ISI   0.006210 -0.024488  0.531805  0.305128  0.229154  1.000000  0.394287
# temp -0.051258 -0.024103  0.431532  0.469594  0.496208  0.394287  1.000000
# RH    0.085223  0.062221 -0.300995  0.073795 -0.039192 -0.132517 -0.527390
# wind  0.018798 -0.020341 -0.028485 -0.105342 -0.203466  0.106826 -0.227116
# rain  0.065387  0.033234  0.056702  0.074790  0.035861  0.067668  0.069491
# area  0.063385  0.044873  0.040122  0.072994  0.049383  0.008258  0.097844
#
#             RH      wind      rain      area
# ...

# %%
plt.subplots(figsize = (15,8))
sns.heatmap(FF.corr(), annot=True,cmap="PiYG")
plt.title("Correlations Among Features", fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Correlations Among Features')

# %% [markdown]
# ### This Corelation heatmap Supports our above Analysis about relation of diffrent factors in occurance of Forest Fires.
